# %% [markdown]
# # Text classification

# %%
# !pip install transformers torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 16.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 23.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 19.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Import Libraries and Load Pre-trained Model

# %%
from transformers import pipeline

# Load a pre-trained sentiment analysis pipeline
sentiment_pipeline = pipeline("sentiment-analysis")

print("Model and tokenizer loaded successfully.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:80: UserWarning:
# Access to the secret `HF_TOKEN` has not been granted on this notebook.
# You will not be requested again.
# Please restart the session if you want to be prompted again.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Model and tokenizer loaded successfully.

# %%
from transformers import pipeline

# Load the sentiment analysis pipeline
sentiment_pipeline = pipeline("text-classification")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %% [markdown]
# ## Classify Sentiment of Text

# %%
sample_text = "What a beautiful day it is outside. The sun is shining, and the birds are singing."

# Use the sentiment analysis pipeline to classify the sentiment of our sample text
result = sentiment_pipeline(sample_text)

# Print the classification result
print(result)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9997908473014832}]

# %%
negative_text = "I'm really disappointed with the service I received. It was slow and unprofessional."

# Use the sentiment pipeline to classify the sentiment of the negative text
result = sentiment_pipeline(negative_text)

# Print the classification result
print(result)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9995773434638977}]

# %% [markdown]
# # Named entity recognition

# %%
from transformers import pipeline
ner_pipeline = pipeline("ner")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %%
# Sample text for NER
text = "Apple Inc. is an American multinational technology company headquartered in Cupertino, California."

# Extract entities using the NER pipeline
entities = ner_pipeline(text)

# Print the extracted entities
print(entities)
# Out:
# [{'entity': 'I-ORG', 'score': 0.9995648, 'index': 1, 'word': 'Apple', 'start': 0, 'end': 5}, {'entity': 'I-ORG', 'score': 0.9994917, 'index': 2, 'word': 'Inc', 'start': 6, 'end': 9}, {'entity': 'I-MISC', 'score': 0.99705374, 'index': 6, 'word': 'American', 'start': 17, 'end': 25}, {'entity': 'I-LOC', 'score': 0.99461293, 'index': 12, 'word': 'Cup', 'start': 76, 'end': 79}, {'entity': 'I-LOC', 'score': 0.8585068, 'index': 13, 'word': '##ert', 'start': 79, 'end': 82}, {'entity': 'I-LOC', 'score': 0.9911663, 'index': 14, 'word': '##ino', 'start': 82, 'end': 85}, {'entity': 'I-LOC', 'score': 0.99815756, 'index': 16, 'word': 'California', 'start': 87, 'end': 97}]

# %%
# Print the extracted entities with their types and confidence scores
for entity in entities:
    print(f"Entity: {entity['word']}, Type: {entity['entity']}, Score: {entity['score']}")
# Out:
# Entity: Apple, Type: I-ORG, Score: 0.9995648264884949
# Entity: Inc, Type: I-ORG, Score: 0.9994916915893555
# Entity: American, Type: I-MISC, Score: 0.9970537424087524
# Entity: Cup, Type: I-LOC, Score: 0.9946129322052002
# Entity: ##ert, Type: I-LOC, Score: 0.8585067987442017
# Entity: ##ino, Type: I-LOC, Score: 0.9911662936210632
# Entity: California, Type: I-LOC, Score: 0.9981575608253479

# %% [markdown]
# The output shows the extracted entities from the sample text along with their types and confidence scores:
#
# * **Apple** and Inc are recognized as parts of the organization name with high confidence scores.
# * **American** is recognized as a miscellaneous entity with a high confidence score.
# * **Cupertino** and **California** are recognized as locations with high confidence scores.
# The prefixes "I-" indicate that these entities are parts of longer entities in the input text.

# %% [markdown]
# # Question answering

# %%
from transformers import pipeline

qa_pipeline = pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]

# %%
# Sample context
context = "Apple Inc. is an American multinational technology company headquartered in Cupertino, California."

# Sample question
question = "Where is Apple Inc. headquartered?"

# Use the QA pipeline to find the answer
answer = qa_pipeline(question=question, context=context)

# Print the answer
print("Answer:", answer["answer"])
# Out:
# Answer: Cupertino, California

# %% [markdown]
# Great! The output shows that the model correctly identified "Cupertino, California" as the location where Apple Inc. is headquartered.

# %% [markdown]
# # Text summarization

# %%
from transformers import pipeline

summarization_pipeline = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
text = """
The Industrial Revolution was the transition to new manufacturing processes in the period from about 1760 to sometime between 1820 and 1840. This transition included going from hand production methods to machines, new chemical manufacturing and iron production processes, the increasing use of steam power, the development of machine tools and the rise of the mechanized factory system. The Industrial Revolution also led to an unprecedented rise in the rate of population growth. Textiles were the dominant industry of the Industrial Revolution in terms of employment, value of output and capital invested. The textile industry was also the first to use modern production methods. The Industrial Revolution began in Great Britain, and many of the technological innovations were of British origin.
"""

# %%
# Generate summary using the summarization pipeline
summary = summarization_pipeline(text, max_length=100, min_length=30, do_sample=False)

# Print the generated summary
print(summary[0]['summary_text'])
# Out:
#  The Industrial Revolution was the transition to new manufacturing processes in the period between 1760 and 1840 . Textiles were the dominant industry of the Industrial Revolution in terms of employment, value of output and capital invested .

# %% [markdown]
# # Translation

# %%
from transformers import pipeline

# Load translation pipeline for English to French
translator = pipeline("translation_en_to_fr", model="Helsinki-NLP/opus-mt-en-fr")
# Out:
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
# English text to translate
english_text = """
The Industrial Revolution was the transition to new manufacturing processes in the period from about 1760 to sometime between 1820 and 1840. This transition included going from hand production methods to machines, new chemical manufacturing and iron production processes, the increasing use of steam power, the development of machine tools and the rise of the mechanized factory system. The Industrial Revolution also led to an unprecedented rise in the rate of population growth. Textiles were the dominant industry of the Industrial Revolution in terms of employment, value of output and capital invested. The textile industry was also the first to use modern production methods. The Industrial Revolution began in Great Britain, and many of the technological innovations were of British origin.
"""

# %%
# Translate the English text to French
translated_text = translator(english_text, clean_up_tokenization_spaces=True)

# Print the translated text
print(translated_text[0]['translation_text'])
# Out:
# La révolution industrielle a été la transition vers de nouveaux procédés de fabrication entre 1820 et 1840, entre 1760 et 1840. Cette transition a consisté à passer des méthodes de production manuelle aux machines, à la fabrication chimique et à la production de fer, à l'utilisation croissante de la vapeur, au développement des machines-outils et à l'essor du système d'usine mécanisé. La révolution industrielle a également entraîné une augmentation sans précédent du taux de croissance démographique.

# %% [markdown]
# This is the translation of the provided English text into French.

# %% [markdown]
# # Zero-shot classification

# %%
from transformers import pipeline

zero_shot_classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
# Text to classify
text = "This movie is amazing! I highly recommend it to everyone."

# Candidate labels
candidate_labels = ["positive", "negative", "neutral"]

# %%
# Perform zero-shot classification
classification_result = zero_shot_classifier(text, candidate_labels)

# Print the classification result
print(classification_result)
# Out:
# {'sequence': 'This movie is amazing! I highly recommend it to everyone.', 'labels': ['positive', 'neutral', 'negative'], 'scores': [0.9836522936820984, 0.010693660005927086, 0.0056540463119745255]}

# %%
# Print the classification result
for label, score in zip(classification_result['labels'], classification_result['scores']):
    print(f"Label: {label}, Score: {score:.4f}")
# Out:
# Label: positive, Score: 0.9837
# Label: neutral, Score: 0.0107
# Label: negative, Score: 0.0057

# %% [markdown]
# The highest score corresponds to the "positive" label, indicating that the input text is classified as positive with high confidence.

# %% [markdown]
# # Computer vision

# %%
pip install transformers torch

# %%
from transformers import ViTFeatureExtractor, ViTForImageClassification
from PIL import Image
import requests

# Load the feature extractor and model
feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224-in21k')
model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224-in21k')

image_url = "https://t4.ftcdn.net/jpg/00/97/58/97/360_F_97589769_t45CqXyzjz0KXwoBZT9PRaWGHRk5hQqQ.jpg"
image = Image.open(requests.get(image_url, stream=True).raw)

# Prepare the image
inputs = feature_extractor(images=image, return_tensors="pt")

# Predict the class of the image
outputs = model(**inputs)
logits = outputs.logits

# Retrieve the highest probability class label
predicted_class_idx = logits.argmax(-1).item()
predicted_class = model.config.id2label[predicted_class_idx]

print(f"Predicted class: {predicted_class}")
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Predicted class: LABEL_1

# %% [markdown]
# # Audio

# %%
pip install transformers librosa torch

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC
import torch
import librosa

# Load the processor and model
processor = Wav2Vec2Processor.from_pretrained("facebook/wav2vec2-base-960h")
model = Wav2Vec2ForCTC.from_pretrained("facebook/wav2vec2-base-960h")

file_name = "/content/test.wav"
audio_input, sampling_rate = librosa.load(file_name, sr=16000)

# Process the audio input for the model
input_values = processor(audio_input, return_tensors="pt", sampling_rate=16000).input_values

# Perform inference
with torch.no_grad():
    logits = model(input_values).logits

# Decode the model output
predicted_ids = torch.argmax(logits, dim=-1)
transcription = processor.batch_decode(predicted_ids)[0]

# Print the transcription
print("Transcribed Text:", transcription)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2ForCTC: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# # Table QA

# %%
from transformers import pipeline

# Initialize the QA pipeline
qa_pipeline = pipeline("question-answering")

data = [
    {"context": "An API is a messenger between apps that allows them to share data and functionality. It's like a waiter in a restaurant, taking your request to the kitchen (the other app) and bringing back the food (the data).", "question": "What is API?"},
    {"context": "LLM stands for Large Language Model. It's a powerful AI system that can understand and generate human-like text. Think of it as a super-powered autocomplete that learns from massive amounts of data to communicate and create text formats.", "question": "What is LLM?"},
    # Add more contexts and questions as needed
]

for item in data:
    result = qa_pipeline(question=item['question'], context=item['context'])
    print(f"Question: {item['question']}")
    print(f"Answer: {result['answer']}\n")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# Question: What is API?
# Answer: a messenger between apps
#
# Question: What is LLM?
# Answer: Large Language Model
